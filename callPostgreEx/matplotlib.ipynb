# %%
from app.db import connect
import pandas as pd


con = connect()
datefrom = '2004-01-01'
dateto = '2004-03-31'
query = "SELECT * FROM customers_countries_orders('{0}','{1}')".format(datefrom, dateto)
df = pd.read_sql_query(query, con)
con.close()

df.to_csv('myCSV/countrietotal.csv', index=False)
# Out:
# Connecting...

# %%
import numpy as np

df=pd.read_csv('myCSV/countrietotal.csv')
data = df.set_index('country')
#data = pd.DataFrame(df, index=np.arange(1, len(df)))
data = pd.DataFrame(data)
"""
# Select sub set of Dataframe based on row/column indices in list
subsetDf = df.loc[['Australia', 'UK', 'US'],['totalamount', 'City']]

options = ['Math', 'Commerce']
rslt_df = dataframe[dataframe['Stream'].isin(options)]

# selecting rows based on condition not in
rslt_df = dataframe.loc[~dataframe['Stream'].isin(options)]

# selecting rows based on condition AND
rslt_df = dataframe[(dataframe['Age'] == 21) & dataframe['Stream'].isin(options)]
"""
subsetDf = data.loc[['Australia', 'UK', 'US'],['totalamount']]
#data.loc["Australia"]
countries=["Australia","UK","US"]
#data1=data.loc[countries]
data1=data.loc[countries]
subsetDf
#data1[(data1["totalamount"] >= 20000) & (data1["totalamount"] <= 35000)]
#data.sort_index()
#np.average(data["totalamount"])
#data["totalamount"].sum()
#data.rank(method="min")
#data.loc[2:5]
#data.value_counts()
#data.at["UK","totalamount"]
#data1
#data1.index.tolist()
#np.array(data1["totalamount"])
#data[data["country"] == 'Australia']
# Out:
#            totalamount
# country
# Australia     35562.36
# UK            28605.73
# US           297541.19

# %%
df=pd.read_csv('myCSV/ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(2, 3, 1)
ax2 = fig.add_subplot(2, 3, 2)
ax3 = fig.add_subplot(2, 3, 3)
ax = fig.add_subplot(2,3,4)

ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30))
ax3.plot(np.random.standard_normal(50).cumsum(), color="black", linestyle="dashed")
ax.plot(np.random.standard_normal(30).cumsum(), color="red",linestyle="dashed", marker="o");

# %%
fig, ax = plt.subplots()

ax.plot(np.random.standard_normal(1000).cumsum());

#slice x coordinate to ticks (pika). Ex: here the range is 0-1000
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
#enter the labels of ticks
labels = ax.set_xticklabels(["one", "two", "three", "four", "five"], rotation=30, fontsize=8)
#enter the label of x-coordinate
ax.set_xlabel("Stages")
#enter the title 
ax.set_title("My first matplotlib plot")
# Out:
# Text(0.5, 1.0, 'My first matplotlib plot')

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color="black", label="one");
ax.plot(np.random.randn(1000).cumsum(), color="blue", linestyle="dashed", label="two");
ax.plot(np.random.randn(1000).cumsum(), color="orange", linestyle="dotted", label="three");
ax.legend()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1)
number_of_colors = len(data1)

hexa = '0123456789ABCDEF'

colors = ["#" + ''.join([random.choice(hexa) for j in range(6)]) for i in range(number_of_colors)]

x_pos = np.arange(number_of_colors)

# Create bars with different colors
plt.bar(x_pos, np.array(data1["totalamount"]), color=colors)
# Create names on the x-axis
plt.xticks(x_pos, data1.index)

#ax.plot.bar(data1, color=data1["colors"])
#data1.plot.bar(ax=ax[0], color=colors)
#data1.plot.barh(ax=ax[1])

#fig.savefig(fname="myCSV/figpath.pdf", dpi=400, format="pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 7
#       3 number_of_colors = len(data1)
#       5 hexa = '0123456789ABCDEF'
# ----> 7 colors = ["#" + ''.join([random.choice(hexa) for j in range(6)]) for i in range(number_of_colors)]
#       9 x_pos = np.arange(number_of_colors)
#      11 # Create bars with different colors
#
# Cell In [6], line 7, in <listcomp>(.0)
#       3 number_of_colors = len(data1)
#       5 hexa = '0123456789ABCDEF'
# ----> 7 colors = ["#" + ''.join([random.choice(hexa) for j in range(6)]) for i in range(number_of_colors)]
#       9 x_pos = np.arange(number_of_colors)
#      11 # Create bars with different colors
#
# Cell In [6], line 7, in <listcomp>(.0)
#       3 number_of_colors = len(data1)
#       5 hexa = '0123456789ABCDEF'
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.gridspec import GridSpec
import numpy as np
from itertools import cycle
import random

#fig, (ax1, ax2) = plt.subplots(2,1)
# create a cycler to continously loop over a discrete colormap
#cycler = cycle(cm.tab10.colors)
N = len(data1)

hexa = '0123456789ABCDEF'

colors = ["#" + ''.join([random.choice(hexa) for j in range(6)]) for i in range(N)]
#colors = cycle(cm.tab10.colors)

#N = 10
x = np.arange(N).astype(int)
y = np.array(data1["totalamount"])
country = np.array(data1.index)

f = plt.figure()
gs = GridSpec(1, 2)
#ax0 = f.add_subplot(gs[0, :-1])
ax1 = f.add_subplot(gs[0, :-1])
ax2 = f.add_subplot(gs[:, -1])

ax1.bar(x, y)
for i,p in enumerate(ax1.patches):
    p.set_facecolor(colors[i])    
    p.set_label(country[i])
handles, labels = ax1.get_legend_handles_labels()    
ax1.set_xticks(x, np.array(data1.index))
#ax1.legend()
ax2.axis(False)
ax2.legend(handles, labels)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.gridspec import GridSpec
import numpy as np
from itertools import cycle

# create a cycler to continously loop over a discrete colormap
cycler = cycle(cm.tab10.colors)

N = 10
x = np.arange(N).astype(int)
y = np.random.uniform(5, 15, N)

f = plt.figure()
gs = GridSpec(2, 4)
ax0 = f.add_subplot(gs[0, :-1])
ax1 = f.add_subplot(gs[1, :-1])
ax2 = f.add_subplot(gs[:, -1])

for i in x:
    ax0.plot(x, np.exp(-x / (i + 1)), label="Sample %s" % (i + 1))
h, l = ax0.get_legend_handles_labels()

ax1.bar(x, y)
for p in ax1.patches:
    p.set_facecolor(next(cycler))

ax2.axis(False)
ax2.legend(h, l)
plt.tight_layout()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
N = len(data1)
ind = np.argmax(np.array(data1["totalamount"]))
"""
expl = ()
for i in range(N):    
    if i == ind:
        expl += (0.1,)
    else:
        expl += (0,)
"""
expl = [0.1 if i==ind else 0. for i in range(N) ]
#print(tuple(expl))
fig1, ax1 = plt.subplots()

r, t, u = ax1.pie(np.array(data1["totalamount"]), explode=expl,labels=data1.index, 
                  autopct=lambda p:f'{p:.2f}% \n{p*sum(np.array(data1["totalamount"]))/100 :.2f}', 
                  shadow=True, startangle=90)
ax1.legend(r, data1.index, title="Countries", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
fig1.savefig(fname="myCSV/figpath1.pdf", dpi=400, format="pdf")

# %%
import matplotlib.pyplot as plt

x = [10, 50, 30, 20]
labels = ['Surfing', 'Soccer', 'Baseball', 'Lacrosse']

fig, ax = plt.subplots(figsize=(6, 6))

patches, texts, pcts = ax.pie(
    x, labels=labels, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'},
    startangle=90)
# For each wedge, set the corresponding text label color to the wedge's
# face color.
for i, patch in enumerate(patches):
  texts[i].set_color(patch.get_facecolor())
plt.setp(pcts, color='white')
plt.setp(texts, fontweight=600)
ax.set_title('Sport Popularity', fontsize=18)
plt.tight_layout()

"""
r1, t1, u1 = ax1.pie(np.array(grouped_countries["sum"]), explode=expl1,labels=grouped_countries.index, 
                  autopct=lambda p:f'{p:.2f}% \n{p*sum(np.array(grouped_countries["sum"]))/100 :.2f}', 
                  shadow=True, startangle=90, pctdistance=1.1, labeldistance=1.3)
"""
