# %%
from app import simplePostgreData as sd

cntr = 'UK'
jsi = sd.selectProds(cntr)
jsi
# Out:
#      firstname    lastname              address     city state country  \
# 0       QZXFPN  WARSHQYISP  2635899973 Dell Way  TINSRLS  None      UK
# 1       QZXFPN  WARSHQYISP  2635899973 Dell Way  TINSRLS  None      UK
# 2       QZXFPN  WARSHQYISP  2635899973 Dell Way  TINSRLS  None      UK
# 3       QZXFPN  WARSHQYISP  2635899973 Dell Way  TINSRLS  None      UK
# 4       QZXFPN  WARSHQYISP  2635899973 Dell Way  TINSRLS  None      UK
# ...        ...         ...                  ...      ...   ...     ...
# 2950    TDPBNH  HYFQGVAFDH  2899662573 Dell Way  EAROQVT  None      UK
# 2951    TDPBNH  HYFQGVAFDH  2899662573 Dell Way  EAROQVT  None      UK
# 2952    TDPBNH  HYFQGVAFDH  2899662573 Dell Way  EAROQVT  None      UK
# 2953    TDPBNH  HYFQGVAFDH  2899662573 Dell Way  EAROQVT  None      UK
# 2954    TDPBNH  HYFQGVAFDH  2899662573 Dell Way  EAROQVT  None      UK
#
#                    title  price quantity  total
# 0     ALABAMA GOODFELLAS  24.99        3  74.97
# ...
